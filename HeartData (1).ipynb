# %% [markdown]
# ## Step-1: Import required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Step-2: Upload dataset

# %%
df=pd.read_csv("heart.csv.xls")
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# ## Step-3: Data Preprocessing

# %%
The given dataset was already cleaned data
# Out:
#   Cell In[62], line 1
#     The given dataset was already cleaned data
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Step-4: EDA(Exploratory data analysis)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.sample()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 854   65    1   3       138   282    1        0      174      0      1.4
#
#      slope  ca  thal  target
# 854      1   1     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(723)

# %%
# visualize the target variables
sns.countplot(x='target',data=df,palette="bwr",color='red',edgecolor='black')
# Out:
# C:\Users\Shreya\AppData\Local\Temp\ipykernel_22992\2317472840.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='target',data=df,palette="bwr",color='red',edgecolor='black')
# <Axes: xlabel='target', ylabel='count'>

# %%
# based on gender check target variable and border hue
sns.countplot(x='target',hue="sex",data=df,palette="bwr",color="red",edgecolor='black')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
## check based on age categories heart diseases
#create age categories
bins=[29, 40,50,60,70,80]
labels=["30-39","40-49","50-59","60-69","70-79"]
df["age_group"]=pd.cut(df["age"],bins=bins,labels=labels)
sns.countplot(x="age_group",hue="target",data=df,palette="bwr",color="red",edgecolor="black")
# Out:
# <Axes: xlabel='age_group', ylabel='count'>

# %% [markdown]
# ## Step-5:Divide the Data into X and Y

# %%
x=df.drop( columns={"target","age_group"},axis=1)
y=df["target"]

# %%
#train and test splitting
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.2, random_state=42)

# %%
##Tarin the model
from sklearn.linear_model import LogisticRegression

##Load the model
model=LogisticRegression()

##Fit the model
trainmodel.fit(x_train, y_train)

##Make prdictions
y_pred = train_model.predict(x_test)
y_pred
# Out:
# C:\Users\Shreya\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 11
#       8 model.fit(x_train, y_train)
#      10 ##Make prdictions
# ---> 11 y_pred = train_model.predict(x_test)
#      12 y_pred
#
# NameError: name 'train_model' is not defined

# %%
## find accuracy
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy of Logistic Regression model is: ",accuracy)
# Out:
# Accuracy of Logistic Regression model is:  0.7951219512195122

# %%
#check loss function
from sklearn.metrics import  log_loss
logloss=log_loss(y_test,y_pred)
print("Log Loss of Logistic Regression model is:",logloss)
# Out:
# Log Loss of Logistic Regression model is: 7.384553377282539

# %%
## combined actual vs predicted
comparison=pd.DataFrame({"Actual":y_test,"Predicted": y_pred})
comparison
# Out:
#      Actual  Predicted
# 527       1          1
# 359       1          1
# 447       0          0
# 31        1          1
# 621       0          0
# ..      ...        ...
# 832       1          0
# 796       1          1
# 644       1          1
# 404       0          0
# 842       0          0
#
# [205 rows x 2 columns]

# %%
#find the confusion matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[74, 28],
#        [14, 89]])

# %%
#save the final model
import joblib
joblib.dump(final_model,'HeartData.pkl')
print("Model saved successfully as 'HeartData.pkl'")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 #save the final model
#       2 import joblib
# ----> 3 joblib.dump(final_model,'HeartData.pkl')
#       4 print("Model saved successfully as 'HeartData.pkl'")
#
# NameError: name 'final_model' is not defined
